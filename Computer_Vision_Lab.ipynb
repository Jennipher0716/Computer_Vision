# %% [markdown]
# QN 1: Ethical issues with computer vision applications.

# %%
import pandas as pd
import numpy as np

# %%
from IPython import get_ipython
ipython = get_ipython()

# %% [markdown]
#  Ethical issues with computer vision applications.
#
#  https://www.europarl.europa.eu/RegData/etudes/STUD/2020/634452/EPRS_STU(2020)634452_EN.pdf

# %%
from IPython.display import Image

# %%
Image("Al.png")

# %% [markdown]
# 1. That as Al progresses, so is the growing fear of its displacement of human capital.
#
# 2. While some activities like information and data processing, production, farming, fishing etc may be automotable, activities like reasoning and decision making and coordinating, developing, managing, and advising were less likely than others to be automatable.
#
# 3. Big players in the Al industry have more power that they are using to influence directly and indirectly both political and social changes to their own benefit. For example Facebook and Google seen as the only sources of in time information especially for the younger generation.
#
# 4. Al used to opress and supress people for instance in the case of China and its surveillance system that has placed more than 30 million people in detension camps.
#
# 5. The debate on if Al systems may have a right to personhood as they evolve which in its own sense is a moral dilema.
#
# 6. If the information al uses has been input and trained by a human, how to expect fair treatment? For instance in cases of CVs and applications, where a machine identifies name by region of descent.

# %% [markdown]
# QN 2:
#
#
#
#
# Use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done.

# %%
from IPython.display import Image

# %% [markdown]
# A grassy tree filled field with a lot of kites in the air.

# %%
Image("Generated Image.png")

# %% [markdown]
# 1) There is no tree that I see in the image except grass.
#
# 2) The kites look more of baloons than Kites.
